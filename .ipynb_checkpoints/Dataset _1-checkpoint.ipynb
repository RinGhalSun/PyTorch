# %% [markdown]
# # Dataset 1 Preview

# %%
import os
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
from torch.utils.data import DataLoader
from PIL import Image
import torch.nn.functional as F
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder  
from torchvision import models
from torch import optim
import pandas as pd
# %matplotlib inline

# %%
def show_image(image, label):
    print("Label :" + train.classes[label] + "(" + str(label) + ")")
    plt.imshow(image.permute(1, 2, 0))

# %% [markdown]
# ## Dataset 1

# %%
data_dir1 = "../input/New Plant Diseases Dataset"
train_dir1 = data_dir1 + "/train"
valid_dir1 = data_dir1 + "/valid"
diseases1 = os.listdir(train_dir1)
print(diseases1)
print(len(diseases1))
# Out:
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___healthy', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Strawberry___healthy', 'Strawberry___Leaf_scorch', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___healthy', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite
# ...

# %%
nums = {}
for disease in diseases1:
    nums[disease] = len(os.listdir(train_dir1 + '/' + disease))
    
img_per_class = pd.DataFrame(nums.values(), index=nums.keys(), columns=["no. of images"])
img_per_class
# Out:
#                                                     no. of images
# Apple___Apple_scab                                           2017
# Apple___Black_rot                                            1987
# Apple___Cedar_apple_rust                                     1760
# Apple___healthy                                              2008
# Blueberry___healthy                                          1816
# Cherry_(including_sour)___healthy                            1826
# Cherry_(including_sour)___Powdery_mildew                     1683
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot           1642
# Corn_(maize)___Common_rust_                                  1907
# Corn_(maize)___healthy                                       1859
# Corn_(maize)___Northern_Leaf_Blight                          1908
# Grape___Black_rot                                            1888
# Grape___Esca_(Black_Measles)                                 1920
# ...

# %%
n_train = 0
for value in nums.values():
    n_train += value
print(f"There are {n_train} images for training")
# Out:
# There are 70296 images for training

# %%
train1 = ImageFolder(train_dir1, transform=transforms.ToTensor())
valid1 = ImageFolder(valid_dir1, transform=transforms.ToTensor())

# %%
show_image(*train1[0])
# Out:
# Label :Apple___Apple_scab(0)

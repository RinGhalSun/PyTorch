# %% [markdown]
# # Dataset 2 Preview

# %%
import os
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
from torch.utils.data import DataLoader
from PIL import Image
import torch.nn.functional as F
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder  
from torchvision import models
from torch import optim
import pandas as pd
# %matplotlib inline

# %%
def show_image(image, label):
    print("Label :" + train1.classes[label] + "(" + str(label) + ")")
    plt.imshow(image.permute(1, 2, 0))

# %%
data_dir1 = "../input/plant disease regonition"
train_dir1 = data_dir1 + "/train"
valid_dir1 = data_dir1 + "/valid"
diseases1 = os.listdir(train_dir1)
print(diseases1)
print(len(diseases1))
# Out:
# ['Healthy', 'Powdery', 'Rust']
# 3

# %%
nums = {}
for disease in diseases1:
    nums[disease] = len(os.listdir(train_dir1 + '/' + disease))
    
img_per_class = pd.DataFrame(nums.values(), index=nums.keys(), columns=["no. of images"])
img_per_class
# Out:
#          no. of images
# Healthy            458
# Powdery            430
# Rust               434

# %%
n_train = 0
for value in nums.values():
    n_train += value
print(f"There are {n_train} images for training")
# Out:
# There are 1322 images for training

# %%
train1 = ImageFolder(train_dir1, transform=transforms.ToTensor())
valid1 = ImageFolder(valid_dir1, transform=transforms.ToTensor())

# %%
show_image(*train1[0])
# Out:
# Label :Healthy(0)
